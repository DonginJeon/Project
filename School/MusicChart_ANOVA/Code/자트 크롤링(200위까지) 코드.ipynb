# %%
#top50 제목과 가수추출

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from tqdm.notebook import tqdm
import pandas as pd

# %%
date1=20220529

# %%
url = f"https://www.genie.co.kr/chart/top200?ditc=D&rtm=N&ymd={date1}"
url2 = f"https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=2"
url3 = f"https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=3"
url4 = f"https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=4"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    track_data = []

    tracks = soup.select("#body-content > div.newest-list > div > table > tbody > tr")
    for track in tracks:
        title_element = track.select_one("a.title.ellipsis")
        artist_element = track.select_one("a.artist.ellipsis")
        

        if title_element and artist_element:
            title = title_element.text.strip()
            artist = artist_element.text.strip()
            

            track_data.append({
                "Title": title,
                "Artist": artist,
            
            })
        else:
            title = title_element.text.strip() if title_element else "N/A"
            artist = artist_element.text.strip() if artist_element else "N/A"
            
            
            print(f"Missing element - Title: {title}, Artist: {artist}")

    df = pd.DataFrame(track_data)
    print(df)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
    

response2 = requests.get(url2, headers=headers)
if response2.status_code == 200:
    soup2 = BeautifulSoup(response2.content, "html.parser")
    
    track_data2 = []

    tracks2 = soup2.select("#body-content > div.newest-list > div > table > tbody > tr")
    for track2 in tracks2:
        title_element2 = track2.select_one("a.title.ellipsis")
        artist_element2 = track2.select_one("a.artist.ellipsis")
        

        if title_element2 and artist_element2:
            title2 = title_element2.text.strip()
            artist2 = artist_element2.text.strip()
            

            track_data2.append({
                "Title": title2,
                "Artist": artist2,
            
            })
        else:
            title2 = title_element2.text.strip() if title_element2 else "N/A"
            artist2 = artist_element2.text.strip() if artist_element2 else "N/A"
            
            
            print(f"Missing element - Title2: {title2}, Artist2: {artist2}")

    df2 = pd.DataFrame(track_data2)
    print(df2)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

response3 = requests.get(url3, headers=headers)
if response3.status_code == 200:
    soup3 = BeautifulSoup(response3.content, "html.parser")
    
    track_data3 = []

    tracks3 = soup3.select("#body-content > div.newest-list > div > table > tbody > tr")
    for track3 in tracks3:
        title_element3 = track3.select_one("a.title.ellipsis")
        artist_element3 = track3.select_one("a.artist.ellipsis")
        

        if title_element3 and artist_element3:
            title3 = title_element3.text.strip()
            artist3 = artist_element3.text.strip()
            

            track_data3.append({
                "Title": title3,
                "Artist": artist3,
            
            })
        else:
            title3 = title_element3.text.strip() if title_element3 else "N/A"
            artist3 = artist_element3.text.strip() if artist_element3 else "N/A"
            
            
            print(f"Missing element - Title3: {title3}, Artist3: {artist3}")

    df3 = pd.DataFrame(track_data3)
    print(df3)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

response4 = requests.get(url4, headers=headers)
if response4.status_code == 200:
    soup4 = BeautifulSoup(response4.content, "html.parser")
    
    track_data4 = []

    tracks4 = soup4.select("#body-content > div.newest-list > div > table > tbody > tr")
    for track4 in tracks4:
        title_element4 = track4.select_one("a.title.ellipsis")
        artist_element4 = track4.select_one("a.artist.ellipsis")
        

        if title_element4 and artist_element4:
            title4 = title_element4.text.strip()
            artist4 = artist_element4.text.strip()
            

            track_data4.append({
                "Title": title4,
                "Artist": artist4,
            
            })
        else:
            title4 = title_element4.text.strip() if title_element4 else "N/A"
            artist4 = artist_element4.text.strip() if artist_element4 else "N/A"
            
            
            print(f"Missing element - Title4: {title4}, Artist4: {artist4}")

    df4 = pd.DataFrame(track_data4)
    print(df4)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
#                                                 Title  \
# 0               That That (Prod. & Feat. SUGA of BTS)
# 1                                              TOMBOY
# 2                                           LOVE DIVE
# 3                                              사랑인가 봐
# 4                                봄여름가을겨울 (Still Life)
# 5                                              나의 X에게
# 6                                             LOVE me
# 7                                      Feel My Rhythm
# 8                                                취중고백
# 9                                            FEARLESS
# 10                                                신호등
# 11                                               ZOOM
# 12                               GANADARA (Feat. 아이유)
# 13                                          사랑은 늘 도망가
# 14                                      다정히 내 이름을 부르면
# 15                               정이라고 하자 (Feat. 10CM)
# 16                                             듣고 싶을까
# 17                                             MY BAG
# 18                                               Stay
# 19                                               INVU
# 20                                             ELEVEN
# 21         회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)
# 22                                              Celeb
# 23                                           우리들의 블루스
# 24  19금\n                                         ...
# 25                                    strawberry moon
# 26                   리무진 (Feat. MINO) (Prod. by GRAY)
# 27                                         Next Level
# 28                                            Weekend
# 29                                           너의 모든 순간
# 30                                            언제나 사랑해
# 31                   Stronger (What Doesn't Kill You)
# 32                                             너를 생각해
# 33                                         스물다섯, 스물하나
# 34                                            내가 아니라도
# 35                                   That's Hilarious
# 36                                            내 손을 잡아
# 37                                             바라만 본다
# 38                                     OHAYO MY NIGHT
# 39                                                팡파레
# 40                                         Bad Habits
# 41                                   감동이야 (Feat. 성시경)
# 42                                        다시 만날 수 있을까
# 43                                          Celebrity
# 44                                              호랑수월가
# 45                                           Dynamite
# 46                                          이제 나만 믿어요
# 47                                                 문득
# 48                           흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 49                                                라일락
#
#                            Artist
# 0                        싸이 (Psy)
# 1                         (여자)아이들
# 2                       IVE (아이브)
# 3                멜로망스 (MeloMance)
# 4                    BIGBANG (빅뱅)
# 5                              경서
# 6                       BE'O (비오)
# 7               Red Velvet (레드벨벳)
# 8                             김민석
# 9              LE SSERAFIM (르세라핌)
# 10                            이무진
# 11                     제시 (Jessi)
# 12                            박재범
# 13                            임영웅
# 14                     경서예지 & 전건호
# 15              BIG Naughty (서동현)
# 16                 MSG워너비 (M.O.M)
# 17                        (여자)아이들
# 18  The Kid LAROI & Justin Bieber
# 19                   태연 (TAEYEON)
# 20                      IVE (아이브)
# 21                       sokodomo
# 22                       싸이 (Psy)
# 23                            임영웅
# 24                          GAYLE
# 25                       아이유 (IU)
# 26                      BE'O (비오)
# 27                          aespa
# 28                   태연 (TAEYEON)
# 29                            성시경
# 30                    케이시 (Kassy)
# 31                 Kelly Clarkson
# 32                   주시크 (Joosiq)
# 33                            자우림
# 34                             주호
# 35                   Charlie Puth
# 36                       아이유 (IU)
# 37                 MSG워너비 (M.O.M)
# 38           디핵 (D-Hack) & PATEKO
# 39                            다비치
# 40                     Ed Sheeran
# 41                       싸이 (Psy)
# 42                            임영웅
# 43                       아이유 (IU)
# 44                             탑현
# 45                          방탄소년단
# 46                            임영웅
# 47                      BE'O (비오)
# 48                            장범준
# 49                       아이유 (IU)
#                                                 Title                 Artist
# 0                                                  고백       멜로망스 (MeloMance)
# 1                     Counting Stars (Feat. Beenzino)              BE'O (비오)
# 2                                    늦은 밤 헤어지긴 너무 아쉬워            케이시 (Kassy)
# 3                                            Blueming               아이유 (IU)
# 4                                        Every Second             Mina Okabe
# 5                                                2002             Anne-Marie
# 6                                           YOU AND I      WSG워너비 조별경연 (대청봉)
# 7                                                 드라마               아이유 (IU)
# 8               모든 날, 모든 순간 (Every day, Every Moment)                     폴킴
# 9                                       낙하 (With 아이유)              AKMU (악뮤)
# 10                                          Tiny Riot              Sam Ryder
# 11                                     밤하늘의 별을 (2020)                     경서
# 12                                SMILEY (Feat. BIBI)             YENA (최예나)
# 13                                               어제처럼                     폴킴
# 14                      Loving You Girl (Feat. Hkeem)            Peder Elias
# 15                                             Butter                  방탄소년단
# 16                   찰나가 영원이 될 때 (The Eternal Moment)           마크툽 (Maktub)
# 17                                             미친 것처럼                  V.O.S
# 18                                              헤픈 우연            헤이즈 (Heize)
# 19                                                 서랍                   10CM
# 20                                              Seoul                 볼빨간사춘기
# 21                                        At My Worst            Pink Sweat$
# 22           오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)           마크툽 (Maktub)
# 23                                       롤린 (Rollin')   브레이브걸스 (Brave girls)
# 24     사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)                    호미들
# 25                                        My Universe       Coldplay & 방탄소년단
# 26                                        Off My Face          Justin Bieber
# 27  만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. by TOIL)           베이식 (Basick)
# 28                                 눈이 오잖아 (Feat. 헤이즈)                    이무진
# 29                                             오래된 노래  Standing Egg (스탠딩 에그)
# 30                                                HOT        세븐틴 (SEVENTEEN)
# 31                                Permission to Dance                  방탄소년단
# 32                     에잇 (Prod. & Feat. SUGA of BTS)               아이유 (IU)
# 33                                             Savage                  aespa
# 34                                              RUN2U           STAYC (스테이씨)
# 35                                        나는 트로트가 싫어요                    임창정
# 36                                       주저하는 연인들을 위해                    잔나비
# 37                                 12 : 45 (Stripped)                  Etham
# 38                                            봄 to 러브                   10CM
# 39                                             아무래도 난           주시크 (Joosiq)
# 40                          어떻게 이별까지 사랑하겠어, 널 사랑하는 거지              AKMU (악뮤)
# 41                                                아로하                    조정석
# 42                                          Step Back           GOT the beat
# 43                                                무지개                    임영웅
# 44  19금\n                                         ...          Justin Bieber
# 45                         너의 번호를 누르고 (Prod. by 영화처럼)                    #안녕
# 46                                     Because Of You                  Ne-Yo
# 47                                      Dun Dun Dance      오마이걸 (OH MY GIRL)
# 48                                                 여행                 볼빨간사춘기
# 49  Hey Mama (Feat. Nicki Minaj & Bebe Rexha & Afr...           David Guetta
#                                                 Title  \
# 0                                   밝게 빛나는 별이 되어 비춰줄게
# 1                                                 Bad
# 2           작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 3                                                 아버지
# 4                                       Way Back Home
# 5                                              METEOR
# 6                                               비와 당신
# 7                                            Timeless
# 8                                     추억은 만남보다 이별에 남아
# 9        Savage Love (Laxed - Siren Beat) (BTS Remix)
# 10                                                겨울잠
# 11                                     Lovesick Girls
# 12                                     우리가 헤어져야 했던 이유
# 13                            어떻게 지내 (Prod. by VAN.C)
# 14                                              존재만으로
# 15                              취기를 빌려 (취향저격 그녀 X 산들)
# 16                                                 선물
# 17                       그게 더 편할 것 같아 (N번째 연애 X 멜로망스)
# 18                                    비가 오는 날엔 (2021)
# 19                                           Memories
# 20                                  늦은 밤 너의 집 앞 골목길에서
# 21        Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 22                                       Dance Monkey
# 23  사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마...
# 24                                                밤편지
# 25                                     그날에 나는 맘이 편했을까
# 26                                          parachute
# 27                                       첫눈처럼 너에게 가겠다
# 28                                 밤이 깊었네 (Feat. 헤이즈)
# 29                                   Dreams Come True
# 30                                        어푸 (Ah puh)
# 31                                         Happy Song
# 32                    쉬어 (Feat. MINO) (Prod. by GRAY)
# 33                                           With you
# 34                                                 흰눈
# 35                                          A bientot
# 36                                            마음을 드려요
# 37                          Wake Up (Prod. by 코드 쿤스트)
# 38                                                 안녕
# 39                                           잊을 수 있을까
# 40                                       Shape Of You
# 41                                                있잖아
# 42                                                 시작
# 43                                       Light Switch
# 44                                                멜로디
# 45                                          마지막 너의 인사
# 46                       너, 너 (N번째 연애 X 휘인 (Whee In))
# 47                                  그래서 그래 (Feat. 윤하)
# 48                                           Darl＋ing
# 49                                                 희재
#
#                                                Artist
# 0                                                 송이한
# 1                                         Christopher
# 2                                               방탄소년단
# 3                                                 임영웅
# 4                                           숀 (SHAUN)
# 5                                        창모 (CHANGMO)
# 6                                                 이무진
# 7                                               SG워너비
# 8                                                 정동하
# 9                    Jawsh 685 & Jason Derulo & 방탄소년단
# 10                                           아이유 (IU)
# 11                                          BLACKPINK
# 12                                          비비 (BIBI)
# 13                                          오반 (OVAN)
# 14                                               원슈타인
# 15                                                 산들
# 16                                   멜로망스 (MeloMance)
# 17                                   멜로망스 (MeloMance)
# 18                                        헤이즈 (Heize)
# 19                                           Maroon 5
# 20                                                 노을
# 21                                       PATEKO (파테코)
# 22                                        Tones And I
# 23                                                잔나비
# 24                                           아이유 (IU)
# 25                                                이예준
# 26                                             John K
# 27                                        에일리 (Ailee)
# 28                                           싸이 (Psy)
# 29                                              aespa
# 30                                           아이유 (IU)
# 31                                   멜로망스 (MeloMance)
# 32  아넌딜라이트 (Anandelight) & Unofficialboyy & BE'O (...
# 33                                           지민 & 하성운
# 34                                먼데이 키즈 (Monday Kiz)
# 35                                                임영웅
# 36                                           아이유 (IU)
# 37  개코 & 아우릴고트 (OUREALGOAT) & SINCE & 안병웅 & Tabber...
# 38                                                 폴킴
# 39                                                 노을
# 40                                         Ed Sheeran
# 41                                                 폴킴
# 42                                          가호 (Gaho)
# 43                                       Charlie Puth
# 44                                         ASH ISLAND
# 45                                        헤이즈 (Heize)
# 46                                       휘인 (Whee In)
# 47                                   에픽하이 (EPIK HIGH)
# 48                                    세븐틴 (SEVENTEEN)
# 49                                                성시경
#                                          Title  \
# 0                                           봄날
# 1                            사실 나는 (Feat. 전건호)
# 2                                    Starlight
# 3                      시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 4                                       사랑의 인사
# 5   네가 없는 밤 (Feat. ASH ISLAND) (Prod. by GRAY)
# 6                                         지금 난
# 7                                         좋아좋아
# 8                                        말리지 마
# 9                                   손이 참 곱던 그대
# 10                                         물고기
# 11                                          초대
# 12                                   Real Love
# 13                                       Ashes
# 14                    Kiss Me More (Feat. SZA)
# 15                                      사랑해 진짜
# 16                                       우연히 봄
# 17                           Paris in the Rain
# 18                            어땠을까 (Feat. 박정현)
# 19                              운전만해 (We Ride)
# 20                                  ONCE AGAIN
# 21                                   잠이 오질 않네요
# 22                                  너의 번호를 누르고
# 23                              이제는 (Feat. 화사)
# 24                        Can't Control Myself
# 25                   끝나지 않은 얘기 (Feat. 다이나믹 듀오)
# 26                                       상상더하기
# 27                                        연애편지
# 28                                        ASAP
# 29                             Don't Start Now
# 30                                 DON QUIXOTE
# 31                                  안녕 (Hello)
# 32                                     Dolphin
# 33                                       Drive
# 34                                  Love story
# 35                                         사랑역
# 36                                   초록을거머쥔우리는
# 37                            너에게 못했던 내 마지막 말은
# 38                      서툰 이별을 하려해 (Feat. 전상근)
# 39               비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 40                                      NANANA
# 41                                      행복한 나를
# 42                              Christmas Tree
# 43                                        내 곁에
# 44                                       하루만 더
# 45                                         하지마
# 46                                    그대와 달 아래
# 47   VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 48                                        아무노래
# 49                                    사랑해요 그대를
#
#                                                Artist
# 0                                               방탄소년단
# 1                                                경서예지
# 2                                          태일 (TAEIL)
# 3                                        케이윌 (K.Will)
# 4                                   WSG워너비 조별경연 (비로봉)
# 5                                           BE'O (비오)
# 6                                           오반 (OVAN)
# 7                                                 조정석
# 8                                             (여자)아이들
# 9                                                 임영웅
# 10                                   백예린 (Yerin Baek)
# 11                                   멜로망스 (MeloMance)
# 12                                  오마이걸 (OH MY GIRL)
# 13                                            Stellar
# 14                                           Doja Cat
# 15                                                임영웅
# 16                                     로꼬 & 유주 (YUJU)
# 17                                               Lauv
# 18                                           싸이 (Psy)
# 19                               브레이브걸스 (Brave girls)
# 20                        윈터 (WINTER) & 닝닝 (NINGNING)
# 21                                                장범준
# 22                                                김나영
# 23                                           싸이 (Psy)
# 24                                       태연 (TAEYEON)
# 25                           릴러말즈 (Leellamarz) & TOIL
# 26                                        라붐 (LABOUM)
# 27                                                임영웅
# 28                                       STAYC (스테이씨)
# 29                                           Dua Lipa
# 30                                    세븐틴 (SEVENTEEN)
# 31                                           조이 (JOY)
# 32                                  오마이걸 (OH MY GIRL)
# 33                                       미연 ((여자)아이들)
# 34                                             볼빨간사춘기
# 35                                                임영웅
# 36                                                잔나비
# 37                                                다비치
# 38                                    윤토벤 (YounToven)
# 39                                   에픽하이 (EPIK HIGH)
# 40                                         GOT7 (갓세븐)
# 41                                  WSG워너비 조별경연 (신선봉)
# 42                                                  V
# 43                                       태연 (TAEYEON)
# 44                                     빅마마 (Big Mama)
# 45                           릴러말즈 (Leellamarz) & TOIL
# 46                                                 탑현
# 47  미란이 (MIRANI) & 먼치맨 (MUNCHMAN) & Khundi Panda &...
# 48                                          지코 (ZICO)
# 49                                                임영웅

# %%
#장르추출

# %%
#1~50

# %%
driver = webdriver.Chrome()
driver.get(f'https://www.genie.co.kr/chart/top200?ditc=D&rtm=N&ymd={date1}')

genres = []

for i in range(0, 50):
    more_info=driver.find_elements(By.CSS_SELECTOR,'.mask')
    more_info[i].click()
    time.sleep(2)
    genre=driver.find_element(By.XPATH, "//*[@id='body-content']/div[2]/div[2]/ul/li[2]/span[2]").text
    genres.append(genre)
    driver.back()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[7], line 10
#       8 more_info[i].click()
#       9 time.sleep(2)
# ---> 10 genre=driver.find_element(By.XPATH, "//*[@id='body-content']/div[2]/div[2]/ul/li[2]/span[2]").text
#      11 genres.append(genre)
#      12 driver.back()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=128.0.6613.138)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF64C549412+29090]
# 	(No symbol) [0x00007FF64C4BE239]
# 	(No symbol) [0x00007FF64C37B1DA]
# 	(No symbol) [0x00007FF64C34FAF5]
# 	(No symbol) [0x00007FF64C3FE2C7]
# 	(No symbol) [0x00007FF64C415EB1]
# 	(No symbol) [0x00007FF64C3F6493]
# 	(No symbol) [0x00007FF64C3C09D1]
# 	(No symbol) [0x00007FF64C3C1B31]
# 	GetHandleVerifier [0x00007FF64C86871D+3302573]
# 	GetHandleVerifier [0x00007FF64C8B4243+3612627]
# 	GetHandleVerifier [0x00007FF64C8AA417+3572135]
# 	GetHandleVerifier [0x00007FF64C605EB6+801862]
# 	(No symbol) [0x00007FF64C4C945F]
# 	(No symbol) [0x00007FF64C4C4FB4]
# 	(No symbol) [0x00007FF64C4C5140]
# 	(No symbol) [0x00007FF64C4B461F]
# 	BaseThreadInitThunk [0x00007FF94ABE257D+29]
# 	RtlUserThreadStart [0x00007FF94B84AF28+40]

# %%
#51~100

# %%
driver2 = webdriver.Chrome()
driver2.get(f'https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=2')

genres2 = []

for k in range(0, 50):
    more_info2=driver2.find_elements(By.CSS_SELECTOR,'.mask')
    more_info2[k].click()
    time.sleep(2)
    genre2=driver2.find_element(By.XPATH, "//*[@id='body-content']/div[2]/div[2]/ul/li[2]/span[2]").text
    genres2.append(genre2)
    driver2.back()
    time.sleep(2)

# %%
#101~150

# %%
driver3 = webdriver.Chrome()
driver3.get(f'https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=3')

genres3 = []

for k in range(0, 50):
    more_info3=driver3.find_elements(By.CSS_SELECTOR,'.mask')
    more_info3[k].click()
    time.sleep(2)
    genre3=driver3.find_element(By.XPATH, "//*[@id='body-content']/div[2]/div[2]/ul/li[2]/span[2]").text
    genres3.append(genre3)
    driver3.back()
    time.sleep(2)

# %%
#151~200

# %%
driver4 = webdriver.Chrome()
driver4.get(f'https://www.genie.co.kr/chart/top200?ditc=D&ymd={date1}&hh=16&rtm=N&pg=4')

genres4 = []

for k in range(0, 50):
    more_info4=driver4.find_elements(By.CSS_SELECTOR,'.mask')
    more_info4[k].click()
    time.sleep(2)
    genre4=driver4.find_element(By.XPATH, "//*[@id='body-content']/div[2]/div[2]/ul/li[2]/span[2]").text
    genres4.append(genre4)
    driver4.back()
    time.sleep(2)

# %%
df['genre']=''
df2['genre']=''
df3['genre']=''
df4['genre']=''

# %%
df['genre']=genres
df2['genre']=genres2
df3['genre']=genres3
df4['genre']=genres4

# %%
df_ = pd.concat([df,df2,df3,df4], ignore_index=True)

# %%
df_.to_csv(f"{date1}.csv")

# %%
df
# Out:
#                                                 Title  \
# 0               That That (Prod. & Feat. SUGA of BTS)
# 1                                              TOMBOY
# 2                                           LOVE DIVE
# 3                                              사랑인가 봐
# 4                                봄여름가을겨울 (Still Life)
# 5                                              나의 X에게
# 6                                             LOVE me
# 7                                      Feel My Rhythm
# 8                                                취중고백
# 9                                            FEARLESS
# 10                                                신호등
# 11                                               ZOOM
# 12                               GANADARA (Feat. 아이유)
# 13                                          사랑은 늘 도망가
# 14                                      다정히 내 이름을 부르면
# 15                               정이라고 하자 (Feat. 10CM)
# 16                                             듣고 싶을까
# 17                                             MY BAG
# 18                                               Stay
# 19                                               INVU
# 20                                             ELEVEN
# 21         회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)
# 22                                              Celeb
# 23                                           우리들의 블루스
# 24  19금\n                                         ...
# 25                                    strawberry moon
# 26                   리무진 (Feat. MINO) (Prod. by GRAY)
# 27                                         Next Level
# 28                                            Weekend
# 29                                           너의 모든 순간
# 30                                            언제나 사랑해
# 31                   Stronger (What Doesn't Kill You)
# 32                                             너를 생각해
# 33                                         스물다섯, 스물하나
# 34                                            내가 아니라도
# 35                                   That's Hilarious
# 36                                            내 손을 잡아
# 37                                             바라만 본다
# 38                                     OHAYO MY NIGHT
# 39                                                팡파레
# 40                                         Bad Habits
# 41                                   감동이야 (Feat. 성시경)
# 42                                        다시 만날 수 있을까
# 43                                          Celebrity
# 44                                              호랑수월가
# 45                                           Dynamite
# 46                                          이제 나만 믿어요
# 47                                                 문득
# 48                           흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 49                                                라일락
#
#                            Artist        genre
# 0                        싸이 (Psy)      댄스 / 가요
# 1                         (여자)아이들       락 / 가요
# 2                       IVE (아이브)      댄스 / 가요
# 3                멜로망스 (MeloMance)    드라마 / OST
# 4                    BIGBANG (빅뱅)       락 / 가요
# 5                              경서      인디 / 가요
# 6                       BE'O (비오)    랩/힙합 / 가요
# 7               Red Velvet (레드벨벳)      댄스 / 가요
# 8                             김민석     발라드 / 가요
# 9              LE SSERAFIM (르세라핌)      댄스 / 가요
# 10                            이무진       락 / 가요
# 11                     제시 (Jessi)    랩/힙합 / 가요
# 12                            박재범  R&B/소울 / 가요
# 13                            임영웅    드라마 / OST
# 14                     경서예지 & 전건호     발라드 / 가요
# 15              BIG Naughty (서동현)      인디 / 가요
# 16                 MSG워너비 (M.O.M)     발라드 / 가요
# 17                        (여자)아이들       락 / 가요
# 18  The Kid LAROI & Justin Bieber      팝 / POP
# 19                   태연 (TAEYEON)      댄스 / 가요
# 20                      IVE (아이브)      댄스 / 가요
# 21                       sokodomo    랩/힙합 / 가요
# 22                       싸이 (Psy)      댄스 / 가요
# 23                            임영웅     발라드 / 가요
# 24                          GAYLE      팝 / POP
# 25                       아이유 (IU)       락 / 가요
# 26                      BE'O (비오)    랩/힙합 / 가요
# 27                          aespa      댄스 / 가요
# 28                   태연 (TAEYEON)      댄스 / 가요
# 29                            성시경    드라마 / OST
# 30                    케이시 (Kassy)     발라드 / 가요
# 31                 Kelly Clarkson      팝 / POP
# 32                   주시크 (Joosiq)      인디 / 가요
# 33                            자우림       락 / 가요
# 34                             주호     발라드 / 가요
# 35                   Charlie Puth      팝 / POP
# 36                       아이유 (IU)    드라마 / OST
# 37                 MSG워너비 (M.O.M)     발라드 / 가요
# 38           디핵 (D-Hack) & PATEKO    랩/힙합 / 가요
# 39                            다비치     발라드 / 가요
# 40                     Ed Sheeran      팝 / POP
# 41                       싸이 (Psy)      댄스 / 가요
# 42                            임영웅     발라드 / 가요
# 43                       아이유 (IU)      댄스 / 가요
# 44                             탑현     발라드 / 가요
# 45                          방탄소년단      댄스 / 가요
# 46                            임영웅     트로트 / 가요
# 47                      BE'O (비오)    랩/힙합 / 가요
# 48                            장범준    드라마 / OST
# 49                       아이유 (IU)      댄스 / 가요
